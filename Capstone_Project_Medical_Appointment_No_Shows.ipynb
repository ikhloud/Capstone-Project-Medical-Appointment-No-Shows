# %% [markdown]
# # Capstone Project : Medical Appointment No Shows
# ## by (Kholoud )
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# ## Project Overview
# This project is the capestone for the Data Scientist Nandegree Program from Udacity. I choose to work on a data set that contains Medical Appointment No Shows. This dataset collects information from 100k medical appointments in Brazil and is focused on the question of whether or not patients show up for their appointment . We will analyse the Dataset to find what factors are important for us to know in order to predict if a patient will show up for their scheduled appointment?
#
#
# ## Problem Statement
# A person makes a doctor appointment, receives all the instructions and no-show appointment.
# No-shows have a direct impact on individuals' health. When patients miss appointments, continuity of care is interrupted. Medication efficacy can't be monitored regularly. Preventive services and screenings can't be delivered in a timely manner. Acute illnesses are more likely to go untreated and become chronic conditions with complications. In short, missing an appointment can be severely detrimental to one's health.
# So We will analyse the Dataset to find what factors are important for us to know in order to predict if a patient will show up for their scheduled appointment. And I will do descriptive statistics and visuals to answer questions and see hidden insights.
#
# We are interested to answer the following eight questions:
# - How many patients for female and male?
# - What is the proportion of appointment show-up versus no shows?
# - What is the distribution of the Age for the patient show-up and no-show the appointment?
# - How many patients attended and did not attended the appointment with the Gender?
# - Compare between the patient who show and didn't show the appointment and whether or not the patient is enrolled in Brasilian welfare program?
# - How many patients attended and did not attended the appointment by received SMS?
# - What are hospitals that have the highest number for patients who attended and didn't attend the appointment?
# - Which disease Diabetes, Hypertension, Alcoholism, Handicap patients most showup in at appointment compared with Age ?
# ### Dataset Description:
#
# The original dataset can be downloaded from Kaggle: https://www.kaggle.com/joniarroba/noshowappointments#KaggleV2-May-2016.csv
#
# 110.527 medical appointments its 14 associated variables (characteristics). The most important one if the patient show-up or no-show to the appointment.
#
# The data is contained on 14 variable.
#
# Here is the explanation of each variable :
#
# - 01 - PatientId - Identification of a patient
# - 02 - AppointmentID - Identification of each appointment
# - 03 - Gender - Male or Female
# - 04 - AppointmentDay - The day of the actuall appointment, when they have to visit the doctor.
# - 05 - ScheduledDay - The day someone called or registered the appointment, this is before appointment Day.
# - 06 - Age - How old is the patient.
# - 07 - Neighbourhood - indicates the location of the hospital.
# - 08 - Scholarship - indicates whether or not the patient is enrolled in Brasilian welfare program Bolsa Família.
# - 09 - Hipertension - True or False
# - 10 - Diabetes True or False
# - 11 - Alcoholism True or False
# - 12 - Handcap True or False
# - 13 -SMS_received - 1 if messages sent to the patient else 0.
# - 14 - No-show - Be careful about the encoding of "No-show": it says
# **No** if the patient showed up to their appointment,**Yes** if they did not show up.

# %%
# import statements for all of the packages 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
# In this section, I will load the csv file, look into the data set, clean the data base on the 8 questions I am going to answer , and finall get a clean data set to be analyzed.
#
# ### General Properties
#
# I will load the date set using pandas

# %%
# Load your data and print out a few lines. Perform operations to inspect data
#   types and look for instances of missing or possibly errant data.
# load dataset
df_appoint = pd.read_csv('noshow_appointments.csv')

# %%
#view dataset
# although, you can specify however many you'd like returned
df_appoint.head(10)
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# 5  9.598513e+13        5626772      F  2016-04-27T08:36:51Z
# 6  7.336882e+14        5630279      F  2016-04-27T15:05:12Z
# 7  3.449833e+12        5630575      F  2016-04-27T15:39:58Z
# 8  5.639473e+13        5638447      F  2016-04-29T08:02:16Z
# 9  7.812456e+13        5629123      F  2016-04-27T12:48:25Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# ...

# %%
#this returns a tuple of the dimensions of the dataframe
df_appoint.shape
# Out:
# (110527, 14)

# %%
#this display a concise summary of the dataframe,
# inclouding the number of non-null values in each column
df_appoint.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
# PatientId         110527 non-null float64
# AppointmentID     110527 non-null int64
# Gender            110527 non-null object
# ScheduledDay      110527 non-null object
# AppointmentDay    110527 non-null object
# Age               110527 non-null int64
# Neighbourhood     110527 non-null object
# Scholarship       110527 non-null int64
# Hipertension      110527 non-null int64
# Diabetes          110527 non-null int64
# Alcoholism        110527 non-null int64
# Handcap           110527 non-null int64
# SMS_received      110527 non-null int64
# No-show           110527 non-null object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
#check if there is missing values
df_appoint.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %% [markdown]
# #### we don't have missing values

# %%
#check for duplictes row in the data
sum(df_appoint.duplicated())
# Out:
# 0

# %% [markdown]
# #### we don't have duplictes row

# %%
#this returns the number of unique values in each column 
df_appoint.describe()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105270e+05   1.105270e+05  110527.000000  110527.000000
# mean   1.474963e+14   5.675305e+06      37.088874       0.098266
# std    2.560949e+14   7.129575e+04      23.110205       0.297675
# min    3.921784e+04   5.030230e+06      -1.000000       0.000000
# 25%    4.172614e+12   5.640286e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680573e+06      37.000000       0.000000
# 75%    9.439172e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism        Handcap  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean        0.197246       0.071865       0.030400       0.022248
# std         0.397921       0.258265       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# There is mines vlaue in age columns.It doesn't make sense.

# %%
#this returns the datatypes of the columns
df_appoint.dtypes
# Out:
# PatientId         float64
# AppointmentID       int64
# Gender             object
# ScheduledDay       object
# AppointmentDay     object
# Age                 int64
# Neighbourhood      object
# Scholarship         int64
# Hipertension        int64
# Diabetes            int64
# Alcoholism          int64
# Handcap             int64
# SMS_received        int64
# No-show            object
# dtype: object

# %% [markdown]
# #### we have two columns( ScheduledDay and AppointmentDay),
# #### it's need to change the data types form object to datetime.

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Rename Columns

# %%
# Rename No-show Column and correction spelling mistakes for some Columns
df_appoint.rename(columns={'No-show':'No_show', 'Hipertension':'Hypertension', 'Handcap':'Handicap'}, inplace=True )

# confirm changes 
df_appoint.head(1)
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
#
#          AppointmentDay  Age    Neighbourhood  Scholarship  Hypertension  \
# 0  2016-04-29T00:00:00Z   62  JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handicap  SMS_received No_show
# 0         0           0         0             0      No

# %% [markdown]
# #### Fix ScheduledDay , AppointmentDay datatypes

# %%
#Use the to_datetime function
#I change ScheduledDay cloumns from object to datetime
df_appoint['ScheduledDay'] =  pd.to_datetime(df_appoint['ScheduledDay'])

# %%
#Use the to_datetime function
#I change ScheduledDay cloumns from object to datetime
df_appoint['AppointmentDay'] =  pd.to_datetime(df_appoint['AppointmentDay'])

# %%
#confirm changes
df_appoint.dtypes
# Out:
# PatientId                float64
# AppointmentID              int64
# Gender                    object
# ScheduledDay      datetime64[ns]
# AppointmentDay    datetime64[ns]
# Age                        int64
# Neighbourhood             object
# Scholarship                int64
# Hypertension               int64
# Diabetes                   int64
# Alcoholism                 int64
# Handicap                   int64
# SMS_received               int64
# No_show                   object
# dtype: object

# %% [markdown]
# #### Fix Age cloumn

# %%
df_appoint[df_appoint['Age'] < 0]
# Out:
#           PatientId  AppointmentID Gender        ScheduledDay AppointmentDay  \
# 99832  4.659432e+14        5775010      F 2016-06-06 08:58:13     2016-06-06
#
#        Age Neighbourhood  Scholarship  Hypertension  Diabetes  Alcoholism  \
# 99832   -1         ROMÃO            0             0         0           0
#
#        Handicap  SMS_received No_show
# 99832         0             0      No

# %%
# drop row 
df_appoint.drop(df_appoint.index[99832], inplace=True)

# %%
#confirm changes
df_appoint.describe()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105260e+05   1.105260e+05  110526.000000  110526.000000
# mean   1.474934e+14   5.675304e+06      37.089219       0.098266
# std    2.560943e+14   7.129544e+04      23.110026       0.297676
# min    3.921784e+04   5.030230e+06       0.000000       0.000000
# 25%    4.172536e+12   5.640285e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680572e+06      37.000000       0.000000
# 75%    9.438963e+13   5.725523e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hypertension       Diabetes     Alcoholism       Handicap  \
# count  110526.000000  110526.000000  110526.000000  110526.000000
# mean        0.197248       0.071865       0.030400       0.022248
# std         0.397923       0.258266       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df_appoint.shape
# Out:
# (110526, 14)

# %% [markdown]
# #### Convert data in No_show column from yes &No to 1,0 to easy handling with it
# Here, the 'Yes' and 'No' categorical object data has been replaced with integers for use in statistical
# computations.

# %%
# ‘No’ if the patient showed up to their appointment, and 
# ‘Yes’ if they did not show up.
# ‘No’ = 0 and ‘Yes’ = 1
df_appoint.No_show[df_appoint['No_show'] == 'Yes'] = '1'
df_appoint.No_show[df_appoint['No_show'] == 'No'] = '0'
# Out:
# C:\Users\khloud\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\khloud\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
#convert datatype from object to numrical
df_appoint['No_show'] = df_appoint['No_show'].astype(int)

# %%
df_appoint.head(3)
# Out:
#       PatientId  AppointmentID Gender        ScheduledDay AppointmentDay  Age  \
# 0  2.987250e+13        5642903      F 2016-04-29 18:38:08     2016-04-29   62
# 1  5.589978e+14        5642503      M 2016-04-29 16:08:27     2016-04-29   56
# 2  4.262962e+12        5642549      F 2016-04-29 16:19:04     2016-04-29   62
#
#      Neighbourhood  Scholarship  Hypertension  Diabetes  Alcoholism  Handicap  \
# 0  JARDIM DA PENHA            0             1         0           0         0
# 1  JARDIM DA PENHA            0             0         0           0         0
# 2    MATA DA PRAIA            0             0         0           0         0
#
#    SMS_received  No_show
# 0             0        0
# 1             0        0
# 2             0        0

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis

# %% [markdown]
# ### Univariate Exploration

# %% [markdown]
# #### How many pationts for female and male ?

# %%
# number gender patients
df_appoint.Gender.value_counts()
# Out:
# F    71839
# M    38687
# Name: Gender, dtype: int64

# %%
#The number of female and male

sns.countplot(data = df_appoint, x = 'Gender', palette="Set1",  hue = df_appoint.Gender)
plt.title("The number of female and male")
plt.xlabel(" Gender of the pationt")
plt.ylabel("Number of Gender")
plt.show()

# %% [markdown]
# From the gender graph, it can be seen that number of female patients (71839) and number of male patients (38687).
#
# We can said the number of females are greater than of males patients

# %% [markdown]
# #### Age of the pationt
#
# The most Distribution of Age from 0-5, 25-40 and 45 - 65

# %%
df_appoint.Age.hist(alpha=0.5, bins=20, label='Age')
plt.title("Distribution of Age")
plt.xlabel(" Age of the pationt")
plt.ylabel("Number of Age")
plt.legend();

# %% [markdown]
# #### What is the proportion of appointment show-up versus no shows?

# %%
No_show_prop = df_appoint.No_show.value_counts('No_show')*100
No_show_prop
# Out:
# 0    79.806561
# 1    20.193439
# Name: No_show, dtype: float64

# %%
#plot(kind='pie')
No_show_proportion = df_appoint.No_show.value_counts()
labels = ['show-up', 'No Show']
explode = (0.1, 0)
colors = ['lightskyblue', 'crimson']

plt.pie(No_show_proportion , labels = labels, explode = explode, autopct= '%1.1f%%', counterclock=True, 
        textprops={'color':'black'}, colors = colors , shadow=True);
plt.title(' The proportion of appointment show-up vs. no shows');

# %% [markdown]
# The proportion of patients show-up appointment is 79.8%  and no showe appointment is 20.2% .

# %% [markdown]
# Total attended appointments is far greater than the number of appointments that patients did not show-up for.

# %% [markdown]
# ## Bivariate Exploration

# %% [markdown]
# ### what is the distribution of the Age for the patient show-up and no-show the appointment?

# %% [markdown]
# Here, a filter has been created for use in statistical computations and graph creation. It filters based on
# whether a patient showed up to their appointment (showup) or did not (noshow).

# %%
#create mask
showup = df_appoint.No_show == False
noshow = df_appoint.No_show == True

# %%
df_appoint.Age[showup].mean()
# Out:
# 37.790504154999034

# %%
df_appoint.Age[noshow].mean()
# Out:
# 34.31766656212196

# %%
#plot Distribution
df_appoint.Age[showup].hist(alpha=0.5, bins=20, label='showup', color='blue')
df_appoint.Age[noshow].hist(alpha=0.5, bins=20, label='noshow', color='red')
plt.title("Distribution of Age")
plt.xlabel(" Age of the pationt")
plt.ylabel("Number of showup and noshow")
plt.legend();

# %% [markdown]
# > #### So, based on this plot, it does look like the really young children have a higher attend appointments then the Age from (45-65).
#
# > #### the Age form (23 to 40) and (0-5) have a higher number didn't attend appointments.

# %% [markdown]
# ### How many patients attended and did not attended the appointment with the Gender?

# %%
df_appoint.groupby('Gender').No_show.value_counts()
# Out:
# Gender  No_show
# F       0          57245
#         1          14594
# M       0          30962
#         1           7725
# Name: No_show, dtype: int64

# %%
#The number of patients attended and did not attended the appointment 
sns.countplot(data = df_appoint, x = 'Gender', palette="Set2",  hue = df_appoint.No_show)
plt.title("Distribution of Gender")
plt.xlabel(" Gender of the pationt")
plt.ylabel("Number of showup and noshow")
plt.show()

# %% [markdown]
# > #### 0 means show-up ,1 means no show

# %% [markdown]
# #### The number of female who attended the appointment greater than male.
# #### The number of female who didn't attend the appointment greater than male.

# %% [markdown]
# ### compare between the patient who show and didn't show the appointment and whether or not the patient is enrolled in Brasilian welfare program ?

# %%
#the patient show up the appointment 
df_appoint.Scholarship[showup].value_counts().plot(kind='bar', alpha=0.8, color=['salmon','maroon'])
plt.title("the patient is enrolled in Brasilian welfare program ")
plt.xlabel("Scholarship")
plt.ylabel("Number of show up")
plt.xticks([0, 1],['unenrolled','enrolled'])
plt.legend();

# %%
Scholarship_show = df_appoint.Scholarship[showup].value_counts()
Scholarship_show
# Out:
# 0    79924
# 1     8283
# Name: Scholarship, dtype: int64

# %%
#the patient didn't show the appointment 
df_appoint.Scholarship[noshow].value_counts().plot(kind='bar',alpha=0.8, color=['salmon','maroon'])
plt.title("the patient is enrolled in Brasilian welfare program ")
plt.xlabel("Scholarship")
plt.ylabel("Number of  no show")
plt.xticks([0, 1],['unenrolled','enrolled'])
plt.legend();

# %% [markdown]
# > #### The most of the patient unenrolled in Brasilian welfare program are  attended the appointment.

# %% [markdown]
# ### How many patients attended and did not attended the appointment by received SMS?

# %%
#patients attended the appointment by received SMS 
df_appoint.SMS_received[showup].value_counts().plot(kind='bar', alpha=0.8, color=['crimson','plum'])
plt.title("the patient is received SMS ")
plt.xlabel("Scholarship")
plt.ylabel("Number of show up")
plt.xticks([0, 1],["Didn't received","received SMS"])
plt.legend();

# %%
#patients did not attend the appointment by received SMS 
df_appoint.SMS_received[noshow].value_counts().plot(kind='bar', alpha=0.8, color=['crimson','plum'])
plt.title("the patient is received SMS ")
plt.xlabel("SMS_received")
plt.ylabel("Number of no show")
plt.xticks([0, 1],["Didn't received","received SMS"])
plt.legend();

# %% [markdown]
# > #### SMS text message reminders are may not be effective in reducing the nonattendance rate

# %% [markdown]
# ### What are hospitals that have the highest number for patients who attended and didn't attend the appointment ?

# %%
# the names of hospitals that have the highest number for patients who attended the appointmen
df_appoint.Neighbourhood[showup].value_counts().plot(kind='bar', alpha=0.8, figsize=(17,17))
plt.title("location of the hospital ")
plt.xlabel("Neighbourhood")
plt.ylabel("Number of show up")
plt.legend();

# %% [markdown]
# > #### The top 5 the names of hospitals that have the highest number for patients who attended the appointment
# JARDIM CAMBURI (6200 patients)
# MARIA ORTIZ(4700 patients)
# RESISTENCIA(3500 patients)
# JARDIM DA PENHA(3200 patients)
# SANTA MARTHA(2700 patients)

# %%
#The names of hospitals that have the highest number for patients who didn't attend the appointment
df_appoint.Neighbourhood[noshow].value_counts().plot(kind='bar', alpha=0.8, figsize=(17,17))
plt.title("location of the hospital ")
plt.xlabel("Neighbourhood")
plt.ylabel("Number of no show")
plt.legend();

# %% [markdown]
# > #### The top 5 the names of hospitals that have the highest number for patients who didn't attend the appointment
# JARDIM CAMBURI(1475 patients)
# MARIA ORTIZ(1220 patients)
# ITARARE(930 patients)
# RESISTENCIA(700 patients )
# CENTRO(690 patients)

# %% [markdown]
# ## Multivariate Exploration

# %% [markdown]
# #### Which disease Diabetes, Hypertension, Alcoholism, Handicap patients most showup in at appointment compared with Age ?

# %%
plt.figure(1)
plt.figure(figsize = (15,10))
disease_cols = ['Hypertension', 'Diabetes', 'Alcoholism', 'Handicap']
for col in disease_cols: 
    plt.subplot(int(str(22)+str((disease_cols.index(col)+1))))
    df = pd.DataFrame()
    df['Age'] = range(115) 
    Male = df.Age.apply(lambda x:len(df_appoint[(df_appoint.Age == x) & (df_appoint.Gender == 'M') & (df_appoint[col] == 1) & (df_appoint.No_show == 0 )]))
    Female = df.Age.apply(lambda x:len(df_appoint[(df_appoint.Age == x) & (df_appoint.Gender == 'F') & (df_appoint[col] == 1)& (df_appoint.No_show == 0)]))

    # plot
    plt.plot( df, Male , linestyle='solid', color='blue', linewidth=2)
    plt.plot( df, Female , linestyle='solid', color='lightcoral', linewidth=2)

    plt.legend(['Male','Female'])
    plt.xlabel('Age')
    plt.ylabel('Number of attended')
    plt.title('{} patients'.format(col));

# %% [markdown]
# - Hypertension and Diabetes patients are attending the appointment when compared to other disease . Age ranges from 40 to 80 - with females conversion is better than Males.
# - Alcoholism patients from Male have attending for appointments  are more compared to female and they are in range from 45 to 65.
# -  Male and Female visits for Handicap patient are in the similar range. There isn't much of difference.

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions

# %% [markdown]
# ### Univariate Exploration
# #### How many pationts for female and male ?
#
#
# From the gender graph, it can be seen that number of female patients (71839) and number of male patients (38687).
#
# We can said the number of females are greater than of males patients
#
# #### What is the proportion of appointment show-up versus no shows?
#
# The proportion of patients show-up appointment is 79.8%  and no showe appointment is 20.2% .
#
# Total attended appointments is far greater than the number of appointments that patients did not show-up for.

# %% [markdown]
# ## Bivariate Exploration
#
# #### what is the distribution of the Age for the patient show-up and no-show the appointment?
# >So, based on this plot, it does look like the really young children have a higher attend appointments then the Age from (45-65).
#
# >the Age form (23 to 40) and (0-5) have a higher number didn't attend appointments.
#
# #### How many patients attended and did not attended the appointment with the Gender?)
# > The number of female who attended the appointment greater than male.
# > The number of female who didn't attend the appointment greater than male.
# > female takes way more care of they healthe in comparison to male.
#
# #### compare between the patient who show and didn't show the appointment and whether or not the patient is enrolled in Brasilian welfare program ?
# > The most of the patient unenrolled in Brasilian welfare program are  attended the appointment.
#
# #### How many patients attended and did not attended the appointment by received SMS?
# > SMS text message reminders are may not be effective in reducing the nonattendance rate.
#
# #### What are hospitals that have the highest number for patients who attended and didn't attend the appointment ?
# > The top 5 the names of hospitals that have the highest number for patients who attended the appointment
#
# JARDIM CAMBURI (6200 patients)
# MARIA ORTIZ(4700 patients)
# RESISTENCIA(3500 patients)
# JARDIM DA PENHA(3200 patients)
# SANTA MARTHA(2700 patients)
#
# > The top 5 the names of hospitals that have the highest number for patients who didn't attend the appointment
#
# JARDIM CAMBURI(1475 patients)
# MARIA ORTIZ(1220 patients)
# ITARARE(930 patients)
# RESISTENCIA(700 patients )
# CENTRO(690 patients)

# %% [markdown]
# ## Multivariate Exploration
#
# #### Which disease Diabetes, Hypertension, Alcoholism, Handicap patients most showup in at appointment compared with Age ?
#
# - Hypertension and Diabetes patients are attending the appointment when compared to other disease . Age ranges from 40 to 80 - with females conversion is better than Males.
# - Alcoholism patients from Male have attending for appointments  are more compared to female and they are in range from 45 to 65.
# -  Male and Female visits for Handicap patient are in the similar range. There isn't much of difference.

# %% [markdown]
# ## Conclusions

# %% [markdown]
# Finally we can said the most factors are important for us to know in order to predict if a patient will show up for their scheduled appointments are  the patient unenrolled in Brasilian welfare program as we see most of people who has Scholarship are most likely to miss their appointments showing and patients who don't have a scholarship are show up for their appointments,gender is female, the Age from (45–65) and young children because older caretakers are responsible for them and type of disease Hypertension and Diabetes patients are attending the appointment when compared to other disease.
# Surprisingly, the patients who did not receive sms regarding their appointment have higher number of patients showing up for their appointment.
#
# The distribution of Show-up Rate v.s. SMS_received does not make sense. People who do receive a reminder SMS usually tend to visit the hospital more than those who haven't received an SMS. This discrepancy may cause by human error when collecting data. Or this could be an SMS that was recived while booking an appointment and could possibly have no correlation with the visit probability.
#
# for improvement to this problem can build a model that predict if a patient will show up for their scheduled appointment.
